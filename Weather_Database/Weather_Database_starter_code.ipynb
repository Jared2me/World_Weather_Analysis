# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
print(coordinates[0])
# Out:
# (-42.30789066098229, 3.953590321445745)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 744

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date" : city_date,
                          "Current Description" : city_description
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | rochegda
# Processing Record 3 of Set 1 | urucara
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | arauca
# Processing Record 6 of Set 1 | khash
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | pyshma
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | opobo
# City not found. Skipping...
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | souillac
# Processing Record 16 of Set 1 | matay
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | klaksvik
# Processing Record 19 of Set 1 | touros
# Processing Record 20 of Set 1 | turiacu
# Processing Record 21 of Set 1 | stepnyak
# Processing Record 22 of Set 1 | pisco
# Processing Record 23 of Set 1 | san rafael del sur
# Processing Record 24 of Set 1 | codrington
# Processing Record 25 of Set 1 | cuamba
# Processing Record 26 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 1 | westport
# Processing Record 28 of Set 1 | sao filipe
# Processing Record 29 of Set 1 | qaqortoq
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | marathon
# Processing Record 32 of Set 1 | piacabucu
# Processing Record 33 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 1 | lebowakgomo
# Processing Record 35 of Set 1 | ajdabiya
# Processing Record 36 of Set 1 | dingle
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | mumbwa
# Processing Record 39 of Set 1 | sept-iles
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | hvide sande
# Processing Record 43 of Set 1 | quatre cocos
# Processing Record 44 of Set 1 | turukhansk
# Processing Record 45 of Set 1 | hambantota
# Processing Record 46 of Set 1 | mahe
# Processing Record 47 of Set 1 | ereymentau
# Processing Record 48 of Set 1 | ugoofaaru
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | nioro
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | dikson
# Processing Record 4 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 2 | buchanan
# Processing Record 6 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 2 | windsor
# Processing Record 8 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 2 | sao joao da barra
# Processing Record 10 of Set 2 | totness
# Processing Record 11 of Set 2 | port blair
# Processing Record 12 of Set 2 | bilma
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | knysna
# Processing Record 15 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 2 | sao francisco
# Processing Record 17 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | berlevag
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | sur
# Processing Record 24 of Set 2 | salalah
# Processing Record 25 of Set 2 | dothan
# Processing Record 26 of Set 2 | itupiranga
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | cururupu
# Processing Record 30 of Set 2 | jacareacanga
# Processing Record 31 of Set 2 | vila nova de famalicao
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | tashtagol
# Processing Record 34 of Set 2 | lugazi
# Processing Record 35 of Set 2 | turochak
# Processing Record 36 of Set 2 | sojitra
# Processing Record 37 of Set 2 | okha
# Processing Record 38 of Set 2 | puerto del rosario
# Processing Record 39 of Set 2 | fougamou
# Processing Record 40 of Set 2 | muros
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | katsiveli
# City not found. Skipping...
# Processing Record 44 of Set 2 | pionerskiy
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | los llanos de aridane
# Processing Record 48 of Set 2 | verkhneyarkeyevo
# Processing Record 49 of Set 2 | faya
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | vitkov
# Processing Record 2 of Set 3 | pangody
# Processing Record 3 of Set 3 | coquimbo
# Processing Record 4 of Set 3 | garissa
# Processing Record 5 of Set 3 | havelock
# Processing Record 6 of Set 3 | araouane
# Processing Record 7 of Set 3 | wamba
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | bathsheba
# Processing Record 10 of Set 3 | sladkovo
# Processing Record 11 of Set 3 | krasnokholm
# Processing Record 12 of Set 3 | adrar
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | stornoway
# Processing Record 15 of Set 3 | bubaque
# Processing Record 16 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 3 | pinega
# Processing Record 18 of Set 3 | paracuru
# Processing Record 19 of Set 3 | nalut
# Processing Record 20 of Set 3 | santa maria
# Processing Record 21 of Set 3 | alenquer
# Processing Record 22 of Set 3 | kpandae
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | ornskoldsvik
# Processing Record 26 of Set 3 | lagoa
# Processing Record 27 of Set 3 | kudahuvadhoo
# Processing Record 28 of Set 3 | ostrovnoy
# Processing Record 29 of Set 3 | coihaique
# Processing Record 30 of Set 3 | maine-soroa
# Processing Record 31 of Set 3 | la rioja
# Processing Record 32 of Set 3 | eydhafushi
# Processing Record 33 of Set 3 | marzuq
# Processing Record 34 of Set 3 | iskateley
# Processing Record 35 of Set 3 | port-gentil
# Processing Record 36 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 38 of Set 3 | glinishchevo
# Processing Record 39 of Set 3 | guajara-mirim
# City not found. Skipping...
# Processing Record 40 of Set 3 | dhidhdhoo
# Processing Record 41 of Set 3 | koslan
# Processing Record 42 of Set 3 | vila velha
# Processing Record 43 of Set 3 | rondonopolis
# Processing Record 44 of Set 3 | mahibadhoo
# Processing Record 45 of Set 3 | maniitsoq
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | termiz
# Processing Record 48 of Set 3 | valparaiso
# Processing Record 49 of Set 3 | nosy varika
# Processing Record 50 of Set 3 | harper
# Processing Record 1 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | am timan
# Processing Record 6 of Set 4 | bodden town
# Processing Record 7 of Set 4 | krasnohrad
# Processing Record 8 of Set 4 | burica
# City not found. Skipping...
# Processing Record 9 of Set 4 | omboue
# Processing Record 10 of Set 4 | utica
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | qeshm
# Processing Record 13 of Set 4 | mahanoro
# Processing Record 14 of Set 4 | jalu
# Processing Record 15 of Set 4 | boende
# Processing Record 16 of Set 4 | inongo
# Processing Record 17 of Set 4 | gueret
# Processing Record 18 of Set 4 | bowmore
# Processing Record 19 of Set 4 | mitsamiouli
# Processing Record 20 of Set 4 | tamandare
# Processing Record 21 of Set 4 | chyhyryn
# Processing Record 22 of Set 4 | danville
# Processing Record 23 of Set 4 | teguise
# Processing Record 24 of Set 4 | ughelli
# Processing Record 25 of Set 4 | san jose de ocoa
# Processing Record 26 of Set 4 | sabha
# Processing Record 27 of Set 4 | kerki
# City not found. Skipping...
# Processing Record 28 of Set 4 | nijar
# Processing Record 29 of Set 4 | andilamena
# Processing Record 30 of Set 4 | malinovskiy
# Processing Record 31 of Set 4 | amapa
# Processing Record 32 of Set 4 | nouadhibou
# Processing Record 33 of Set 4 | aden
# Processing Record 34 of Set 4 | roissy-en-brie
# Processing Record 35 of Set 4 | camacha
# Processing Record 36 of Set 4 | san roque
# Processing Record 37 of Set 4 | auchel
# Processing Record 38 of Set 4 | qandala
# Processing Record 39 of Set 4 | paveh
# Processing Record 40 of Set 4 | nieuw amsterdam
# Processing Record 41 of Set 4 | padang
# Processing Record 42 of Set 4 | nanortalik
# Processing Record 43 of Set 4 | fenoarivo
# Processing Record 44 of Set 4 | vestmanna
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | bozoum
# Processing Record 47 of Set 4 | cockburn town
# Processing Record 48 of Set 4 | taoudenni
# Processing Record 49 of Set 4 | bereda
# Processing Record 50 of Set 4 | falun
# Processing Record 1 of Set 5 | petrov val
# Processing Record 2 of Set 5 | tutoia
# Processing Record 3 of Set 5 | takoradi
# Processing Record 4 of Set 5 | sinazongwe
# Processing Record 5 of Set 5 | north bay
# Processing Record 6 of Set 5 | hamilton
# Processing Record 7 of Set 5 | sorland
# Processing Record 8 of Set 5 | san lorenzo
# Processing Record 9 of Set 5 | ambilobe
# Processing Record 10 of Set 5 | san ramon
# Processing Record 11 of Set 5 | ormara
# Processing Record 12 of Set 5 | bom jesus do galho
# Processing Record 13 of Set 5 | leshukonskoye
# Processing Record 14 of Set 5 | beisfjord
# Processing Record 15 of Set 5 | karasjok
# Processing Record 16 of Set 5 | saldanha
# Processing Record 17 of Set 5 | grindavik
# Processing Record 18 of Set 5 | kedzierzyn-kozle
# Processing Record 19 of Set 5 | trairi
# Processing Record 20 of Set 5 | lodwar
# Processing Record 21 of Set 5 | natal
# Processing Record 22 of Set 5 | bonfim
# Processing Record 23 of Set 5 | dovolnoye
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | balkanabat
# Processing Record 26 of Set 5 | galle
# Processing Record 27 of Set 5 | mamallapuram
# Processing Record 28 of Set 5 | hofn
# Processing Record 29 of Set 5 | iqaluit
# Processing Record 30 of Set 5 | abiy adi
# City not found. Skipping...
# Processing Record 31 of Set 5 | rio claro
# Processing Record 32 of Set 5 | belmonte
# Processing Record 33 of Set 5 | turtkul
# City not found. Skipping...
# Processing Record 34 of Set 5 | minna
# Processing Record 35 of Set 5 | yuksekova
# Processing Record 36 of Set 5 | orichi
# Processing Record 37 of Set 5 | vicuna
# Processing Record 38 of Set 5 | suez
# Processing Record 39 of Set 5 | punto fijo
# Processing Record 40 of Set 5 | llangefni
# Processing Record 41 of Set 5 | antofagasta
# Processing Record 42 of Set 5 | nanga eboko
# Processing Record 43 of Set 5 | zavyalovo
# Processing Record 44 of Set 5 | chuy
# Processing Record 45 of Set 5 | veraval
# Processing Record 46 of Set 5 | kalmanka
# Processing Record 47 of Set 5 | ponta do sol
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | necochea
# Processing Record 50 of Set 5 | noyabrsk
# Processing Record 1 of Set 6 | edd
# Processing Record 2 of Set 6 | kautokeino
# Processing Record 3 of Set 6 | tarija
# Processing Record 4 of Set 6 | cayenne
# Processing Record 5 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 6 | lagos
# Processing Record 7 of Set 6 | viedma
# Processing Record 8 of Set 6 | santa maria da boa vista
# Processing Record 9 of Set 6 | hindupur
# Processing Record 10 of Set 6 | ardakan
# Processing Record 11 of Set 6 | rocha
# Processing Record 12 of Set 6 | paso de patria
# Processing Record 13 of Set 6 | sechura
# Processing Record 14 of Set 6 | tukan
# Processing Record 15 of Set 6 | pokaran
# Processing Record 16 of Set 6 | elizabeth city
# Processing Record 17 of Set 6 | kologriv
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | middelburg
# Processing Record 20 of Set 6 | san carlos de bariloche
# Processing Record 21 of Set 6 | pangnirtung
# Processing Record 22 of Set 6 | puerto quijarro
# Processing Record 23 of Set 6 | thetford mines
# Processing Record 24 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 25 of Set 6 | pietarsaari
# Processing Record 26 of Set 6 | kouroussa
# Processing Record 27 of Set 6 | chelyabinsk-70
# City not found. Skipping...
# Processing Record 28 of Set 6 | moose factory
# Processing Record 29 of Set 6 | tabuk
# Processing Record 30 of Set 6 | francistown
# Processing Record 31 of Set 6 | mao
# Processing Record 32 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | juybar
# Processing Record 35 of Set 6 | korla
# Processing Record 36 of Set 6 | honningsvag
# Processing Record 37 of Set 6 | venice
# Processing Record 38 of Set 6 | nsanje
# Processing Record 39 of Set 6 | kayerkan
# Processing Record 40 of Set 6 | qafsah
# City not found. Skipping...
# Processing Record 41 of Set 6 | kilis
# Processing Record 42 of Set 6 | gornyy
# Processing Record 43 of Set 6 | zhezkazgan
# Processing Record 44 of Set 6 | alappuzha
# Processing Record 45 of Set 6 | teno
# Processing Record 46 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 6 | emba
# Processing Record 48 of Set 6 | kulhudhuffushi
# Processing Record 49 of Set 6 | jammal
# Processing Record 50 of Set 6 | margate
# Processing Record 1 of Set 7 | gat
# Processing Record 2 of Set 7 | marshfield
# Processing Record 3 of Set 7 | yanam
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | mogochin
# City not found. Skipping...
# Processing Record 6 of Set 7 | mineros
# Processing Record 7 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 7 | vila franca do campo
# Processing Record 9 of Set 7 | kaukauna
# Processing Record 10 of Set 7 | alora
# Processing Record 11 of Set 7 | islahiye
# Processing Record 12 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 7 | neyshabur
# Processing Record 14 of Set 7 | imbituba
# Processing Record 15 of Set 7 | blyth
# Processing Record 16 of Set 7 | luanda
# Processing Record 17 of Set 7 | galgamacsa
# Processing Record 18 of Set 7 | krasnoselkup
# Processing Record 19 of Set 7 | novo aripuana
# Processing Record 20 of Set 7 | rio gallegos
# Processing Record 21 of Set 7 | barela
# Processing Record 22 of Set 7 | kondinskoye
# Processing Record 23 of Set 7 | oktyabrskoye
# Processing Record 24 of Set 7 | mecca
# Processing Record 25 of Set 7 | thunder bay
# Processing Record 26 of Set 7 | corn island
# Processing Record 27 of Set 7 | sao jose da coroa grande
# Processing Record 28 of Set 7 | eyl
# Processing Record 29 of Set 7 | guayaramerin
# Processing Record 30 of Set 7 | bolobo
# Processing Record 31 of Set 7 | mattawa
# Processing Record 32 of Set 7 | laguna
# Processing Record 33 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 34 of Set 7 | inta
# Processing Record 35 of Set 7 | buenos aires
# Processing Record 36 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 7 | goiania
# Processing Record 38 of Set 7 | zhanaozen
# Processing Record 39 of Set 7 | pahalgam
# Processing Record 40 of Set 7 | maceio
# Processing Record 41 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 7 | lahij
# Processing Record 43 of Set 7 | inyonga
# Processing Record 44 of Set 7 | ginir
# Processing Record 45 of Set 7 | ajaccio
# Processing Record 46 of Set 7 | mandali
# Processing Record 47 of Set 7 | gazni
# City not found. Skipping...
# Processing Record 48 of Set 7 | neubrandenburg
# Processing Record 49 of Set 7 | oyotun
# Processing Record 50 of Set 7 | inhambane
# Processing Record 1 of Set 8 | conceicao do araguaia
# Processing Record 2 of Set 8 | kabompo
# Processing Record 3 of Set 8 | porto novo
# Processing Record 4 of Set 8 | bayir
# Processing Record 5 of Set 8 | filingue
# Processing Record 6 of Set 8 | media luna
# Processing Record 7 of Set 8 | englewood
# Processing Record 8 of Set 8 | saint anthony
# Processing Record 9 of Set 8 | gwembe
# Processing Record 10 of Set 8 | soyo
# Processing Record 11 of Set 8 | jumla
# Processing Record 12 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 13 of Set 8 | yara
# Processing Record 14 of Set 8 | damghan
# Processing Record 15 of Set 8 | san lawrenz
# Processing Record 16 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 8 | agva
# City not found. Skipping...
# Processing Record 18 of Set 8 | bull savanna
# Processing Record 19 of Set 8 | revda
# Processing Record 20 of Set 8 | dudinka
# Processing Record 21 of Set 8 | isla mujeres
# Processing Record 22 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 8 | ewo
# Processing Record 24 of Set 8 | atar
# Processing Record 25 of Set 8 | farafangana
# Processing Record 26 of Set 8 | blagoyevo
# Processing Record 27 of Set 8 | ylivieska
# Processing Record 28 of Set 8 | paramonga
# Processing Record 29 of Set 8 | dholka
# Processing Record 30 of Set 8 | evans
# Processing Record 31 of Set 8 | glenluce
# Processing Record 32 of Set 8 | ovalle
# Processing Record 33 of Set 8 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | kousseri
# Processing Record 35 of Set 8 | kalat
# Processing Record 36 of Set 8 | saquena
# Processing Record 37 of Set 8 | treinta y tres
# Processing Record 38 of Set 8 | buraydah
# Processing Record 39 of Set 8 | altay
# Processing Record 40 of Set 8 | migori
# Processing Record 41 of Set 8 | herne bay
# Processing Record 42 of Set 8 | oranjemund
# Processing Record 43 of Set 8 | tucuman
# Processing Record 44 of Set 8 | jagodje
# Processing Record 45 of Set 8 | ilebo
# Processing Record 46 of Set 8 | bud
# Processing Record 47 of Set 8 | kalmunai
# Processing Record 48 of Set 8 | shahr-e kord
# Processing Record 49 of Set 8 | marawi
# Processing Record 50 of Set 8 | abu dhabi
# Processing Record 1 of Set 9 | tabulbah
# City not found. Skipping...
# Processing Record 2 of Set 9 | mehamn
# Processing Record 3 of Set 9 | richards bay
# Processing Record 4 of Set 9 | suzun
# Processing Record 5 of Set 9 | morondava
# Processing Record 6 of Set 9 | phaltan
# Processing Record 7 of Set 9 | rawson
# Processing Record 8 of Set 9 | mokhotlong
# Processing Record 9 of Set 9 | sharjah
# Processing Record 10 of Set 9 | taunsa
# Processing Record 11 of Set 9 | kamenka
# Processing Record 12 of Set 9 | cornwall
# Processing Record 13 of Set 9 | miraflores
# Processing Record 14 of Set 9 | praia
# Processing Record 15 of Set 9 | walvis bay
# Processing Record 16 of Set 9 | nicoya
# Processing Record 17 of Set 9 | santa rosa
# Processing Record 18 of Set 9 | aberlour
# City not found. Skipping...
# Processing Record 19 of Set 9 | kirovskiy
# Processing Record 20 of Set 9 | sheopur
# Processing Record 21 of Set 9 | taltal
# Processing Record 22 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 23 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 9 | brae
# Processing Record 25 of Set 9 | medea
# Processing Record 26 of Set 9 | bengkulu
# Processing Record 27 of Set 9 | hurghada
# Processing Record 28 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 29 of Set 9 | derzhavinsk
# Processing Record 30 of Set 9 | escanaba
# Processing Record 31 of Set 9 | odesskoye
# Processing Record 32 of Set 9 | arlit
# Processing Record 33 of Set 9 | hammerfest
# Processing Record 34 of Set 9 | lesogorskiy
# Processing Record 35 of Set 9 | ayagoz
# Processing Record 36 of Set 9 | iquitos
# Processing Record 37 of Set 9 | aswan
# Processing Record 38 of Set 9 | zambezi
# Processing Record 39 of Set 9 | puerto madryn
# Processing Record 40 of Set 9 | kozhva
# Processing Record 41 of Set 9 | pishin
# Processing Record 42 of Set 9 | mora
# Processing Record 43 of Set 9 | cadiz
# Processing Record 44 of Set 9 | krk
# Processing Record 45 of Set 9 | teodoro sampaio
# Processing Record 46 of Set 9 | cap malheureux
# Processing Record 47 of Set 9 | cajati
# Processing Record 48 of Set 9 | ouro preto do oeste
# Processing Record 49 of Set 9 | valverde del camino
# Processing Record 50 of Set 9 | koungou
# Processing Record 1 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 10 | rypefjord
# Processing Record 3 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 10 | manyana
# Processing Record 5 of Set 10 | great yarmouth
# Processing Record 6 of Set 10 | malumfashi
# Processing Record 7 of Set 10 | xai-xai
# Processing Record 8 of Set 10 | gilgit
# Processing Record 9 of Set 10 | havre-saint-pierre
# Processing Record 10 of Set 10 | yar-sale
# Processing Record 11 of Set 10 | jamame
# Processing Record 12 of Set 10 | raga
# Processing Record 13 of Set 10 | carutapera
# Processing Record 14 of Set 10 | talnakh
# Processing Record 15 of Set 10 | kowary
# Processing Record 16 of Set 10 | bandarbeyla
# Processing Record 17 of Set 10 | nea peramos
# Processing Record 18 of Set 10 | wilmington
# Processing Record 19 of Set 10 | hirna
# Processing Record 20 of Set 10 | bocaranga
# City not found. Skipping...
# Processing Record 21 of Set 10 | chateaubelair
# Processing Record 22 of Set 10 | tukrah
# Processing Record 23 of Set 10 | mwinilunga
# Processing Record 24 of Set 10 | lykhivka
# Processing Record 25 of Set 10 | tarata
# Processing Record 26 of Set 10 | oberstdorf
# Processing Record 27 of Set 10 | huntingdon
# Processing Record 28 of Set 10 | igrim
# Processing Record 29 of Set 10 | stephenville
# Processing Record 30 of Set 10 | mola di bari
# Processing Record 31 of Set 10 | sacele
# Processing Record 32 of Set 10 | axim
# Processing Record 33 of Set 10 | marabba
# Processing Record 34 of Set 10 | aleppo
# Processing Record 35 of Set 10 | bhatkal
# Processing Record 36 of Set 10 | bolkhov
# Processing Record 37 of Set 10 | ales
# Processing Record 38 of Set 10 | livani
# Processing Record 39 of Set 10 | boa vista
# Processing Record 40 of Set 10 | maralal
# Processing Record 41 of Set 10 | dwarka
# Processing Record 42 of Set 10 | obo
# Processing Record 43 of Set 10 | vawkavysk
# Processing Record 44 of Set 10 | boyabat
# Processing Record 45 of Set 10 | dzaoudzi
# Processing Record 46 of Set 10 | maura
# Processing Record 47 of Set 10 | maun
# Processing Record 48 of Set 10 | scarborough
# Processing Record 49 of Set 10 | the valley
# Processing Record 50 of Set 10 | maua
# Processing Record 1 of Set 11 | novyy urengoy
# Processing Record 2 of Set 11 | salinas
# Processing Record 3 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 4 of Set 11 | gamba
# Processing Record 5 of Set 11 | lyaskelya
# Processing Record 6 of Set 11 | homestead
# Processing Record 7 of Set 11 | vilhena
# Processing Record 8 of Set 11 | puno
# Processing Record 9 of Set 11 | castro alves
# Processing Record 10 of Set 11 | den helder
# Processing Record 11 of Set 11 | vagay
# Processing Record 12 of Set 11 | itabira
# Processing Record 13 of Set 11 | praia da vitoria
# Processing Record 14 of Set 11 | caravelas
# Processing Record 15 of Set 11 | paamiut
# Processing Record 16 of Set 11 | cap-chat
# Processing Record 17 of Set 11 | okakarara
# Processing Record 18 of Set 11 | thompson
# Processing Record 19 of Set 11 | bahia blanca
# Processing Record 20 of Set 11 | kilindoni
# Processing Record 21 of Set 11 | abu samrah
# Processing Record 22 of Set 11 | nisia floresta
# Processing Record 23 of Set 11 | hobyo
# Processing Record 24 of Set 11 | norrtalje
# Processing Record 25 of Set 11 | kitob
# Processing Record 26 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 27 of Set 11 | massaguet
# Processing Record 28 of Set 11 | mega
# Processing Record 29 of Set 11 | nuuk
# Processing Record 30 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 31 of Set 11 | saint-pierre
# Processing Record 32 of Set 11 | sambava
# Processing Record 33 of Set 11 | peddapalli
# Processing Record 34 of Set 11 | los barrios
# Processing Record 35 of Set 11 | port hawkesbury
# Processing Record 36 of Set 11 | marsh harbour
# Processing Record 37 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 11 | kurmanayevka
# Processing Record 39 of Set 11 | severnoye
# Processing Record 40 of Set 11 | staroutkinsk
# Processing Record 41 of Set 11 | henties bay
# Processing Record 42 of Set 11 | baft
# Processing Record 43 of Set 11 | clemency
# Processing Record 44 of Set 11 | zalegoshch
# Processing Record 45 of Set 11 | taperoa
# Processing Record 46 of Set 11 | segezha
# Processing Record 47 of Set 11 | alpena
# Processing Record 48 of Set 11 | libourne
# Processing Record 49 of Set 11 | mitha tiwana
# Processing Record 50 of Set 11 | dimbokro
# Processing Record 1 of Set 12 | agadir
# Processing Record 2 of Set 12 | meulaboh
# Processing Record 3 of Set 12 | leogane
# Processing Record 4 of Set 12 | mezen
# Processing Record 5 of Set 12 | umm kaddadah
# Processing Record 6 of Set 12 | olafsvik
# Processing Record 7 of Set 12 | bayan
# Processing Record 8 of Set 12 | humaita
# Processing Record 9 of Set 12 | constantine
# Processing Record 10 of Set 12 | moundou
# Processing Record 11 of Set 12 | saltpond
# Processing Record 12 of Set 12 | lethem
# Processing Record 13 of Set 12 | bantry
# Processing Record 14 of Set 12 | vestmannaeyjar
# Processing Record 15 of Set 12 | kralendijk
# Processing Record 16 of Set 12 | san pedro
# Processing Record 17 of Set 12 | stratonion
# Processing Record 18 of Set 12 | unye
# City not found. Skipping...
# Processing Record 19 of Set 12 | nardaran
# Processing Record 20 of Set 12 | ndago
# Processing Record 21 of Set 12 | san miguel
# Processing Record 22 of Set 12 | vredendal
# Processing Record 23 of Set 12 | santa fe
# Processing Record 24 of Set 12 | dera ghazi khan
# Processing Record 25 of Set 12 | nigde
# Processing Record 26 of Set 12 | geel
# Processing Record 27 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 12 | naryan-mar
# Processing Record 29 of Set 12 | benghazi
# Processing Record 30 of Set 12 | oksfjord
# Processing Record 31 of Set 12 | heinola
# Processing Record 32 of Set 12 | lodja
# Processing Record 33 of Set 12 | waddan
# Processing Record 34 of Set 12 | cotonou
# Processing Record 35 of Set 12 | aksarka
# Processing Record 36 of Set 12 | severomorsk
# Processing Record 37 of Set 12 | salta
# Processing Record 38 of Set 12 | sivas
# Processing Record 39 of Set 12 | asosa
# Processing Record 40 of Set 12 | san-pedro
# Processing Record 41 of Set 12 | conceicao da barra
# Processing Record 42 of Set 12 | merrill
# Processing Record 43 of Set 12 | itarema
# Processing Record 44 of Set 12 | polyarnyy
# Processing Record 45 of Set 12 | tombouctou
# Processing Record 46 of Set 12 | sibenik
# Processing Record 47 of Set 12 | sisimiut
# Processing Record 48 of Set 12 | gedo
# Processing Record 49 of Set 12 | camana
# Processing Record 50 of Set 12 | panama city
# Processing Record 1 of Set 13 | tromso
# Processing Record 2 of Set 13 | capreol
# Processing Record 3 of Set 13 | miracatu
# Processing Record 4 of Set 13 | igaci
# Processing Record 5 of Set 13 | nara
# Processing Record 6 of Set 13 | kavaratti
# Processing Record 7 of Set 13 | somotillo
# Processing Record 8 of Set 13 | urambo
# Processing Record 9 of Set 13 | jacmel
# Processing Record 10 of Set 13 | saint-georges
# Processing Record 11 of Set 13 | friockheim
# Processing Record 12 of Set 13 | pokhara
# Processing Record 13 of Set 13 | nioki
# Processing Record 14 of Set 13 | paita
# Processing Record 15 of Set 13 | atasu
# Processing Record 16 of Set 13 | olinda
# Processing Record 17 of Set 13 | viransehir
# Processing Record 18 of Set 13 | chicama
# Processing Record 19 of Set 13 | krasnovishersk
# Processing Record 20 of Set 13 | lipari
# Processing Record 21 of Set 13 | adamas
# Processing Record 22 of Set 13 | saint-joseph
# Processing Record 23 of Set 13 | urengoy
# Processing Record 24 of Set 13 | husavik
# Processing Record 25 of Set 13 | kolga
# Processing Record 26 of Set 13 | halifax
# Processing Record 27 of Set 13 | ustka
# Processing Record 28 of Set 13 | ilo
# Processing Record 29 of Set 13 | andra
# Processing Record 30 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 13 | kant
# Processing Record 32 of Set 13 | djibo
# Processing Record 33 of Set 13 | mragowo
# Processing Record 34 of Set 13 | kandi
# Processing Record 35 of Set 13 | riyadh
# Processing Record 36 of Set 13 | tazovskiy
# Processing Record 37 of Set 13 | ouesso
# Processing Record 38 of Set 13 | staryy nadym
# Processing Record 39 of Set 13 | usakos
# Processing Record 40 of Set 13 | abu kamal
# Processing Record 41 of Set 13 | oranjestad
# Processing Record 42 of Set 13 | birao
# Processing Record 43 of Set 13 | yenagoa
# Processing Record 44 of Set 13 | kortkeros
# Processing Record 45 of Set 13 | kasongo-lunda
# Processing Record 46 of Set 13 | jaque
# Processing Record 47 of Set 13 | benjamin constant
# Processing Record 48 of Set 13 | cabedelo
# Processing Record 49 of Set 13 | ybbs
# City not found. Skipping...
# Processing Record 50 of Set 13 | mananjary
# Processing Record 1 of Set 14 | bosaso
# Processing Record 2 of Set 14 | pindiga
# Processing Record 3 of Set 14 | talavera de la reina
# Processing Record 4 of Set 14 | kayes
# Processing Record 5 of Set 14 | la maddalena
# Processing Record 6 of Set 14 | nantucket
# Processing Record 7 of Set 14 | hazaribag
# Processing Record 8 of Set 14 | dedougou
# Processing Record 9 of Set 14 | itaqui
# Processing Record 10 of Set 14 | nova olimpia
# Processing Record 11 of Set 14 | bonavista
# Processing Record 12 of Set 14 | mbeya
# Processing Record 13 of Set 14 | solymar
# Processing Record 14 of Set 14 | goderich
# Processing Record 15 of Set 14 | ciudad bolivar
# Processing Record 16 of Set 14 | linhares
# Processing Record 17 of Set 14 | barra dos coqueiros
# Processing Record 18 of Set 14 | varhaug
# Processing Record 19 of Set 14 | le port
# Processing Record 20 of Set 14 | shenkursk
# Processing Record 21 of Set 14 | gornja tuzla
# Processing Record 22 of Set 14 | hatillo
# Processing Record 23 of Set 14 | vikulovo
# Processing Record 24 of Set 14 | grand baie
# Processing Record 25 of Set 14 | dondo
# Processing Record 26 of Set 14 | santiago de cuba
# Processing Record 27 of Set 14 | kerch
# Processing Record 28 of Set 14 | isheyevka
# Processing Record 29 of Set 14 | zyryanovsk
# Processing Record 30 of Set 14 | cassia
# Processing Record 31 of Set 14 | brandon
# Processing Record 32 of Set 14 | pachino
# Processing Record 33 of Set 14 | gumdag
# Processing Record 34 of Set 14 | bridlington
# Processing Record 35 of Set 14 | oistins
# Processing Record 36 of Set 14 | ambah
# Processing Record 37 of Set 14 | wukari
# Processing Record 38 of Set 14 | okahandja
# Processing Record 39 of Set 14 | svetlogorsk
# Processing Record 40 of Set 14 | rania
# Processing Record 41 of Set 14 | kazanskaya
# Processing Record 42 of Set 14 | pemba
# Processing Record 43 of Set 14 | shakawe
# Processing Record 44 of Set 14 | hwange
# Processing Record 45 of Set 14 | kabo
# Processing Record 46 of Set 14 | bonthe
# Processing Record 47 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 14 | marsabit
# Processing Record 49 of Set 14 | ergani
# Processing Record 50 of Set 14 | arandis
# Processing Record 1 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 15 | tsumeb
# Processing Record 3 of Set 15 | camapua
# Processing Record 4 of Set 15 | nsunga
# Processing Record 5 of Set 15 | kulmbach
# Processing Record 6 of Set 15 | do gonbadan
# Processing Record 7 of Set 15 | troyes
# Processing Record 8 of Set 15 | calabozo
# Processing Record 9 of Set 15 | loanda
# Processing Record 10 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 15 | sebeta
# Processing Record 12 of Set 15 | san luis
# Processing Record 13 of Set 15 | nargana
# Processing Record 14 of Set 15 | bardiyah
# Processing Record 15 of Set 15 | podbrdo
# Processing Record 16 of Set 15 | gobabis
# Processing Record 17 of Set 15 | lock haven
# Processing Record 18 of Set 15 | mahon
# Processing Record 19 of Set 15 | chokwe
# Processing Record 20 of Set 15 | sembe
# Processing Record 21 of Set 15 | rio grande
# Processing Record 22 of Set 15 | brest
# Processing Record 23 of Set 15 | safaga
# Processing Record 24 of Set 15 | marsta
# Processing Record 25 of Set 15 | vuktyl
# Processing Record 26 of Set 15 | belyy yar
# Processing Record 27 of Set 15 | eastbourne
# Processing Record 28 of Set 15 | deder
# Processing Record 29 of Set 15 | tornio
# Processing Record 30 of Set 15 | tanout
# Processing Record 31 of Set 15 | waterloo
# Processing Record 32 of Set 15 | matara
# Processing Record 33 of Set 15 | thionville
# Processing Record 34 of Set 15 | colquiri
# Processing Record 35 of Set 15 | megion
# Processing Record 36 of Set 15 | comodoro rivadavia
# Processing Record 37 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 38 of Set 15 | san rafael
# Processing Record 39 of Set 15 | roald
# Processing Record 40 of Set 15 | nacala
# Processing Record 41 of Set 15 | ocumare del tuy
# Processing Record 42 of Set 15 | ndioum
# Processing Record 43 of Set 15 | srikakulam
# Processing Record 44 of Set 15 | viligili
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 682

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Cape Town -33.9258  18.4232     68.11        72          20       24.16
# 1      Rochegda  62.8000  43.2500     34.81        89          91        9.57
# 2       Urucara  -2.5364 -57.7600     95.16        41          87        4.12
# 3   Port Alfred -33.5906  26.8910     70.18        85           1        3.00
# 4        Arauca   7.0847 -70.7591     85.96        66          20        3.44
# 5         Khash  28.2211  61.2158     68.13        18           0        2.06
# 6       Ushuaia -54.8000 -68.3000     46.06        61          75        5.75
# 7  Longyearbyen  78.2186  15.6401     22.84        63          75        9.22
# 8        Pyshma  56.9523  63.2513     38.19        66         100       17.92
# 9  Punta Arenas -53.1500 -70.9167     48.22        71          75       24.16
#
#   Country                 Date          Current Description
# 0      ZA  2022-10-24 16:36:51                   few clouds
# 1      RU  2022-10-24 16:37:29              overcast clouds
# 2      BR  2022-10-24 16:37:29              overcast clouds
# 3      ZA  2022-10-24 16:37:30                    clear sky
# 4      CO  2022-10-24 16:37:31                   few clouds
# 5      IR  2022-10-24 16:37:31                    clear sky
# 6      AR  2022-10-24 16:37:32                broken clouds
# 7      SJ  2022-10-24 16:37:33                broken clouds
# 8      RU  2022-10-24 16:37:34              overcast clouds
# 9      CL  2022-10-24 16:36:11  light intensity shower rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town      ZA -33.9258  18.4232     68.11        72          20
# 1      Rochegda      RU  62.8000  43.2500     34.81        89          91
# 2       Urucara      BR  -2.5364 -57.7600     95.16        41          87
# 3   Port Alfred      ZA -33.5906  26.8910     70.18        85           1
# 4        Arauca      CO   7.0847 -70.7591     85.96        66          20
# 5         Khash      IR  28.2211  61.2158     68.13        18           0
# 6       Ushuaia      AR -54.8000 -68.3000     46.06        61          75
# 7  Longyearbyen      SJ  78.2186  15.6401     22.84        63          75
# 8        Pyshma      RU  56.9523  63.2513     38.19        66         100
# 9  Punta Arenas      CL -53.1500 -70.9167     48.22        71          75
#
#    Wind Speed          Current Description
# 0       24.16                   few clouds
# 1        9.57              overcast clouds
# 2        4.12              overcast clouds
# 3        3.00                    clear sky
# 4        3.44                   few clouds
# 5        2.06                    clear sky
# 6        5.75                broken clouds
# 7        9.22                broken clouds
# 8       17.92              overcast clouds
# 9       24.16  light intensity shower rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
